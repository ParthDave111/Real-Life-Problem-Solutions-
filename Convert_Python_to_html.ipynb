# %% [markdown]
# <a href="https://colab.research.google.com/github/ParthDave111/Real-Life-Problem-Solutions-/blob/main/Convert_Python_to_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !jupyter nbconvert --to html /content/MScFE_652_PM_GWP1_Grp_9246.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/MScFE_652_PM_GWP1_Grp_9246.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 20 image(s).
# [NbConvertApp] Writing 2497750 bytes to /content/MScFE_652_PM_GWP1_Grp_9246.html
